# %%
# Install packages 
# !pip install sqlalchemy
# !pip install pymysql
# Out:
# Requirement already satisfied: sqlalchemy in c:\users\zachery key\anaconda\lib\site-packages (1.3.20)
# Collecting pymysql
#   Downloading PyMySQL-1.0.2-py3-none-any.whl (43 kB)
# Installing collected packages: pymysql
# Successfully installed pymysql-1.0.2

# %%
import pandas as pd
import numpy as np 
import pymysql
import sqlalchemy
from sqlalchemy import create_engine

# %%
# Connect to database 
connection = pymysql.connect(
        host = '127.0.0.1',
        port =  3306,
        user = 'root',
        password = password,
        database = 'launch_live'
    )
cnx = create_engine('mysql+pymysql://root:'+password+'@localhost:3306/launch_live')

# %%
# Set up data 
people = ['Daniel Willson', 'Kaleigh Watson', 'Amanda Coombs', "Andy Page"]
role = ['VPP', 'LPD', 'COO', 'ED']
workplace = [1,1,1,1]
alma_mater = [2,2,2,2]
people = pd.DataFrame({'name':people, 'role':role, 'workplace_id':workplace, 'alma_mater_id':alma_mater})
people.head()
# Out:
#              name role  workplace_id  alma_mater_id
# 0  Daniel Willson  VPP             1              2
# 1  Kaleigh Watson  LPD             1              2
# 2   Amanda Coombs  COO             1              2
# 3       Andy Page   ED             1              2

# %%
schools = pd.DataFrame({'name':['UVA', 'VT'], 'type':['Public', 'Public'], 'id':[2, 1]})
schools.head()
# Out:
#   name    type  id
# 0  UVA  Public   2
# 1   VT  Public   1

# %%
companies = pd.DataFrame({'name':['Astraea', 'Forge'], 'location':['Charlottesville', 'Charlottesville'], 'id':[2, 1]})
companies.head()
# Out:
#       name         location  id
# 0  Astraea  Charlottesville   2
# 1    Forge  Charlottesville   1

# %%
# Place TABLE into SQL database 
people.to_sql(name='people',
              con=cnx,
              if_exists="append",
              index=True)

companies.to_sql(name='companies',
                con=cnx,
                if_exists="append",
                index=False)

schools.to_sql(name='schools',
              con=cnx,
              if_exists="append",
              index=False)

# %% [markdown]
# Our Project

# %%
import pandas as pd
import numpy as np 
import pymysql
import sqlalchemy
from sqlalchemy import create_engine

# %%
# Connect to database 
connection = pymysql.connect(
        host = '127.0.0.1',
        port =  3306,
        user = 'root',
        password = password,
        database = 'launch_week2'
    )
cnx = create_engine('mysql+pymysql://root:'+password+'@localhost:3306/launch_week2')

# %%
# Import all of the data 
courses_path = "C:/Users/Zachery Key/Desktop/Forge/DataBases/Launch_Databases/COURSES.csv"
school_path = "C:/Users/Zachery Key/Desktop/Forge/DataBases/Launch_Databases/SCHOOLS.csv"
prof_path = "C:/Users/Zachery Key/Desktop/Forge/DataBases/Launch_Databases/PROFS.csv"
city_path = "C:/Users/Zachery Key/Desktop/Forge/DataBases/Launch_Databases/CITIES.csv"
student_path = "C:/Users/Zachery Key/Desktop/Forge/DataBases/Launch_Databases/STUDENTS.csv"

# Import data 
COURSE = pd.read_csv(courses_path)
SCHOOL = pd.read_csv(school_path)
PROF = pd.read_csv(prof_path, encoding= 'unicode_escape')
CITY = pd.read_csv(city_path)
STUDENT = pd.read_csv(student_path)

# %%
SCHOOL.rename(columns={'size ':'num_students'}, inplace =True)
# Out:
# Index(['city_id', 'zipcode', 'city', 'state', 'football', 'hockey', 'baseball',
#        'basketball', 'pop_size'],
#       dtype='object')

# %%
# Place all TABLES into SQL database 
STUDENT.to_sql(name='student',
              con=cnx,
              if_exists="replace",
              index=False)

CITY.to_sql(name='city',
            con=cnx,
            if_exists="replace",
            index=False)

PROF.to_sql(name='prof',
            con=cnx,
            if_exists="replace",
            index=False)

COURSE.to_sql(name='course',
              con=cnx,
              if_exists="replace",
              index=False)

SCHOOL.to_sql(name='school',
             con=cnx,
             if_exists="replace",
             index=False)

# %% [markdown]
# Sample Queries

# %%
# Get one entire table
pd.read_sql("SELECT * from student", con=cnx)
# Out:
#   computing_id first_name  last_name         dob  city_id  course_id school_id
# 0       csksnj   Courtney    Kennedy  10/22/2000        3   SYS 2202      SEAS
# 1       ztk2qv    Zachery        Key   6/20/2000        4  ARCH 3200      SEAS
# 2       jms6vb  Jon Marco    Sanchez   4/20/1969        2   SYS 3034       CAS
# 3        ac9kf      Arwen   Chandler   3/12/2002        1  KINE 1010       CAS
# 4       tes2fl     Taylor      Swift  12/13/1989       10    CS 2150       CAS
# 5       jfe9fu        Joe     Exotic    3/5/1963        3  ENWR 1000       COM
# 6       ggf2re        Guy      Fieri   1/22/1968        7   SYS 2202       COM
# 7       jeb1cu     Justin     Bieber    3/1/1994       13   SYS 2001       NUR
# 8       tej9ab     Thomas  Jefferson   4/13/1743        3    CS 2150       LAW

# %%
# Get all of the professors in the CS department 
pd.read_sql("SELECT * from prof WHERE prof.dept='CS'", con=cnx)
# Out:
#    prof_id         prof_name  city_id school_id  years_worked  tenure dept
# 0        2  Aaron Bloomfield        2      SEAS             1       0   CS
# 1        4       Juan Markot        1      SEAS             2       1   CS

# %%
# Join students with schools 
pd.read_sql("SELECT * from student JOIN school on student.school_id=school.school_id", con=cnx)
# Out:
#   computing_id first_name  last_name         dob  city_id  course_id  \
# 0       csksnj   Courtney    Kennedy  10/22/2000        3   SYS 2202
# 1       ztk2qv    Zachery        Key   6/20/2000        4  ARCH 3200
# 2       jms6vb  Jon Marco    Sanchez   4/20/1969        2   SYS 3034
# 3        ac9kf      Arwen   Chandler   3/12/2002        1  KINE 1010
# 4       tes2fl     Taylor      Swift  12/13/1989       10    CS 2150
# 5       jfe9fu        Joe     Exotic    3/5/1963        3  ENWR 1000
# 6       ggf2re        Guy      Fieri   1/22/1968        7   SYS 2202
# 7       jeb1cu     Justin     Bieber    3/1/1994       13   SYS 2001
# 8       tej9ab     Thomas  Jefferson   4/13/1743        3    CS 2150
#
#   school_id school_id                                       name  \
# 0      SEAS      SEAS  School of Engineering and Applied Science
# 1      SEAS      SEAS  School of Engineering and Applied Science
# 2       CAS       CAS              College of Arts and Sciences
# 3       CAS       CAS              College of Arts and Sciences
# 4       CAS       CAS              College of Arts and Sciences
# 5       COM       COM               Mcintire School of Commerce
# 6       COM       COM               Mcintire School of Commerce
# 7       NUR       NUR                         School of Nursing
# 8       LAW       LAW                                Law School
#
#    num_students  year_founded dean_chair  num_majors
# 0          3589          1901     Rodil            9
# 1          3589          1901     Rodil            9
# 2          7301          1872  Alvarado          152
# 3          7301          1872  Alvarado          152
# 4          7301          1872  Alvarado          152
# 5           357          1923      Najir          11
# 6           357          1923      Najir          11
# 7          1201          1900   Mcdonnel          17
# 8           832          1821    Yashtz            4

# %%
# Get three select columns from student data
pd.read_sql('SELECT computing_id, first_name, last_name FROM student',con=cnx)
# Out:
#   computing_id first_name  last_name
# 0       csksnj   Courtney    Kennedy
# 1       ztk2qv    Zachery        Key
# 2       jms6vb  Jon Marco    Sanchez
# 3        ac9kf      Arwen   Chandler
# 4       tes2fl     Taylor      Swift
# 5       jfe9fu        Joe     Exotic
# 6       ggf2re        Guy      Fieri
# 7       jeb1cu     Justin     Bieber
# 8       tej9ab     Thomas  Jefferson
